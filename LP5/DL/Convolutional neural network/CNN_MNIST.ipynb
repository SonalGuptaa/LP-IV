# %%
import numpy as np

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(train_data,train_label),(test_data,test_label) = fashion_mnist.load_data()

# %%
print("Training data shape:", train_data.shape)
print("Training label shape:", train_label.shape)
print("Testing data shape:", test_data.shape)
print("Testing label shape:", test_label.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Training label shape: (60000,)
# Testing data shape: (10000, 28, 28)
# Testing label shape: (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_data.shape
# Out:
# (60000, 28, 28)

# %%
train_label
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_data.shape
# Out:
# (10000, 28, 28)

# %%
test_label
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %%
plt.figure()
plt.imshow(train_data[0])
plt.colorbar()

# %%
train_data = train_data / 255.0

test_data = test_data / 255.0

# %%
plt.figure(figsize=(20,20))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_data[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_label[i]])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_data, train_label, epochs=30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4941 - accuracy: 0.8279
# Epoch 2/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3729 - accuracy: 0.8658
# Epoch 3/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3342 - accuracy: 0.8775
# Epoch 4/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3120 - accuracy: 0.8856
# Epoch 5/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2935 - accuracy: 0.8923
# Epoch 6/30
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2794 - accuracy: 0.8960
# Epoch 7/30
# 1220/1875 [==================>...........] - ETA: 2s - loss: 0.2706 - accuracy: 0.8992

# %%
test_loss, test_acc = model.evaluate(test_data,  test_label, verbose=2)

print('\nTest accuracy:', test_acc)
